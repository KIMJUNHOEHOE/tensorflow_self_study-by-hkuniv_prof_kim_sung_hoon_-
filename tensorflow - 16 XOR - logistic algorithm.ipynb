# %% [markdown]
# ### XOR

# %% [markdown]
# - X => eXclusive, 서로 다르면 1, 같으면 0
# - 하나의 네트워크 로직으로는 xor문제를 풀수 없었음
# - 여러개의 네트워크 로직을 섞으면 xor 문제를 풀 수 있음

# %% [markdown]
# ### How can we learn W1,W2,B1,B2 from training data?
# > - Back propagation<br>
# - cost 함수의 최소값을 찾아가는 gradientDescent Optimizer<br>
# - W,B를 찾아내기 위해서는 error에 대한 미분값을 구해야 하는데, 여러 레이어로 겹쳐있기 때문에 여러 과정을 통해서 미분값을 구해야 한다. 하지만 forward propagation으로는 W,B값을 찾기가 어려웠음 <br>
# - NN의 W1,W2,B1,B2를 learning 하기 위해서 backpropagation(chain rule)

# %% [markdown]
# ### Logistic
# #### 1개의 네트워크를 사용한 XOR 풀이의 문제

# %%
# Lab 9 XOR을 1개의 layer를 사용할 경우 1,1 => 0 이 되는 것을 예측하지 못함
import tensorflow as tf
import numpy as np

tf.set_random_seed(777)  # for reproducibility
learning_rate = 0.1

x_data = [[0, 0], # XOR에서 input data
          [0, 1],
          [1, 0],
          [1, 1]]
y_data = [[0], # Y값은 0,1 분류 => softmax 안써도 되고, 분류인 sigmoid, maximumlikehood ftn 쓴다.
          [1],
          [1],
          [0]]
x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

X = tf.placeholder(tf.float32, [None, 2])
Y = tf.placeholder(tf.float32, [None, 1])

W = tf.Variable(tf.random_normal([2, 1]), name='weight') # XOR 풀려는데 layer 1개?
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis using sigmoid: tf.div(1., 1. + tf.exp(tf.matmul(X, W)))
hypothesis = tf.sigmoid(tf.matmul(X, W) + b)

# cost/loss function - maximumlike degree cost ftn
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) *
                       tf.log(1 - hypothesis))

train = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# Accuracy computation
# True if hypothesis>0.5 else False
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# Launch graph
with tf.Session() as sess:
    # Initialize TensorFlow variables
    sess.run(tf.global_variables_initializer())

    for step in range(10001):
        sess.run(train, feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, sess.run(cost, feed_dict={
                  X: x_data, Y: y_data}), sess.run(W))

    # Accuracy report
    h, c, a = sess.run([hypothesis, predicted, accuracy],
                       feed_dict={X: x_data, Y: y_data})
    print("\nHypothesis: ", h, "\nCorrect: ", c, "\nAccuracy: ", a)
# Out:
# 0 0.87597954 [[0.7863567]
#  [0.6628261]]
# 100 0.6957122 [[0.23303682]
#  [0.16537341]]
# 200 0.6942727 [[0.1468633 ]
#  [0.11071217]]
# 300 0.69365716 [[0.09652311]
#  [0.07720933]]
# 400 0.69337857 [[0.06380111]
#  [0.05348315]]
# 500 0.69325244 [[0.0423411 ]
#  [0.03682906]]
# 600 0.693195 [[0.02819196]
#  [0.02524734]]
# 700 0.69316894 [[0.0188217 ]
#  [0.01724866]]
# 800 0.6931571 [[0.01259337]
#  [0.01175304]]
# 900 0.69315165 [[0.00844097]
#  [0.00799206]]
# 1000 0.6931492 [[0.00566576]
#  [0.00542594]]
# 1100 0.69314814 [[0.00380732]
#  [0.00367921]]
# 1200 0.69314766 [[0.0025608 ]
#  [0.00249235]]
# 1300 0.6931474 [[0.00172364]
#  [0.00168707]]
# 1400 0.6931473 [[0.00116083]
#  [0.00114128]]
# 1500 0.6931472 [[0.00078214]
#  [0.0007717 ]]
# 1600 0.6931472 [[0.00052721]
#  [0.00052162]]
# 1700 0.6931471 [[0.00035546]
#  [0.00035248]]
# 1800 0.6931472 [[0.00023971]
#  [0.00023812]]
# 1900 0.6931472 [[0.00016166]
#  [0.00016081]]
# 2000 0.6931472 [[0.00010905]
# ...
